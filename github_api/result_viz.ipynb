# %%
import matplotlib.pyplot as plt
import numpy as np
from main import iterate_all_search_terms, vex_filetype_count

BAR_WIDTH = 5
BAR_HEIGHT = 10

iterate_all_search_terms(False, False)

x = []
y = []

for item in vex_filetype_count:
    for key in item.keys():
        x.append(key)
        y.append(item[key])

x = np.array(x)
y = np.array(y)

plt.figure(figsize=(len(vex_filetype_count) * BAR_WIDTH, BAR_HEIGHT))
bar = plt.bar(x,y)
plt.bar_label(bar, fmt=lambda y: f'{y}')
plt.show()

print(vex_filetype_count)

vex_filetype_count = []
# Out:
# [{'CycloneDX-ft:json-ext:json': 1096}, {'CycloneDX-ft:xml-ext:xml': 164}, {'CSAF-ft:json-ext:json': 30352}, {'OpenVEX-ft:json-ext:json': 1348}, {'CycloneDX-ft:json-ext:json': 1096}, {'CycloneDX-ft:xml-ext:xml': 164}, {'CSAF-ft:json-ext:json': 30352}, {'OpenVEX-ft:json-ext:json': 1348}]
